# %%
a=df("AllClaims")

# %%
a.count()
# Out:
# 835942

# %%
a.peek()
# Out:
# clm_gid:String             = 00000066465001994419
# dt:Timestamp               = 2010-10-12 00:00:00.0
# svc_ln_seq:Integer         = 1
# ptnt_gid:String            = 00000000000337629945
# prodt:String               = 99215
# diagArr:Array(String,true) = WrappedArray(244.9, 268.9, 272.0, 401.1, 530.11, 733.90, 780.53, 789.00, , , , )
# phyn_key:String            = 00000000000000806042
# phyn_gid:String            = 00000000000000806042
# clm_typ:String             = PX_DX
# clm_sts:String             = null
# day_sply:Integer           = null
# drg_id:String              = null
# adj_svc_unit_nbr:Integer   = 0
# prodt_strgth:String        = null
# qty:Decimal(38,7)          = null
# dt_mth:String              = 201701

# %%
a.smvFreqHist("prodt")
# Out:
# Histogram of prodt: String sorted by Frequency
# key                      count      Pct    cumCount   cumPct
# 99213                    41642    4.98%       41642    4.98%
# 99214                    35122    4.20%       76764    9.18%
# 36415                    30199    3.61%      106963   12.80%
# 85025                    26384    3.16%      133347   15.95%
# 80053                    19229    2.30%      152576   18.25%
# 97110                    12002    1.44%      164578   19.69%
# 97140                     8590    1.03%      173168   20.72%
# 99232                     8135    0.97%      181303   21.69%
# 99212                     7914    0.95%      189217   22.64%
# 96413                     7384    0.88%      196601   23.52%
# 85610                     6756    0.81%      203357   24.33%
# 80061                     6623    0.79%      209980   25.12%
# 77413                     6072    0.73%      216052   25.85%
# 71020                     6067    0.73%      222119   26.57%
# ...

# %%
a.select("ptnt_gid").distinct().count()
# Out:
# 4490
